# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A66-F804
#
#  Directory of C:\Users\Rokaya Neeraj\Full Stack Data Science\Python\Pandas
#
# 03/28/2022  01:28 PM    <DIR>          .
# 03/28/2022  01:28 PM    <DIR>          ..
# 03/28/2022  01:26 PM    <DIR>          .ipynb_checkpoints
# 03/28/2022  01:28 PM               588 Pandas.ipynb
#                1 File(s)            588 bytes
#                3 Dir(s)  18,105,241,600 bytes free

# %%
df = pd.read_csv(r"C:/Users/Rokaya Neeraj/Downloads/carbon_nanotubes.csv")
df.head()
# Out:
#   Chiral indice n Chiral indice m Initial atomic coordinate u  \
# 0           2;1;0        679005;0                    701318;0
# 1           2;1;0        717298;0                    642129;0
# 2           2;1;0        489336;0                    303751;0
# 3           2;1;0        413957;0                    632996;0
# 4           2;1;0        334292;0                    543401;0
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    017033;0                    721039;0
# 1                    231319;0                    738414;0
# 2                    088462;0                    477676;0
# 3                    040843;0                    408823;0
# 4                     15989;0                    303349;0
#
#   Calculated atomic coordinates u'  Calculated atomic coordinates v'
# 0                         730232;0                           17014.0
# 1                          65675;0                          232369.0
# ...

# %% [markdown]
# Two data types in pandas:
#     1. Dataframe - Complete table
#     2. Series - one single column or one single row

# %%
df = pd.read_csv(r"C:/Users/Rokaya Neeraj/Downloads/carbon_nanotubes.csv", header = None) #default header
df.head()
# Out:
#                  0                1                            2  \
# 0  Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 1            2;1;0         679005;0                     701318;0
# 2            2;1;0         717298;0                     642129;0
# 3            2;1;0         489336;0                     303751;0
# 4            2;1;0         413957;0                     632996;0
#
#                              3                            4  \
# 0  Initial atomic coordinate v  Initial atomic coordinate w
# 1                     017033;0                     721039;0
# 2                     231319;0                     738414;0
# 3                     088462;0                     477676;0
# 4                     040843;0                     408823;0
#
#                                   5                                 6
# 0  Calculated atomic coordinates u'  Calculated atomic coordinates v'
# 1                          730232;0                             17014
# ...

# %%
df = pd.read_csv(r"C:/Users/Rokaya Neeraj/Downloads/carbon_nanotubes.csv", names = ["a","b","c","d","e","f"]) #passing header
df.head()
# Out:
#                                a                            b  \
# Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 2;1;0                   679005;0                     701318;0
# 2;1;0                   717298;0                     642129;0
# 2;1;0                   489336;0                     303751;0
# 2;1;0                   413957;0                     632996;0
#
#                                            c                            d  \
# Chiral indice n  Initial atomic coordinate v  Initial atomic coordinate w
# 2;1;0                               017033;0                     721039;0
# 2;1;0                               231319;0                     738414;0
# 2;1;0                               088462;0                     477676;0
# 2;1;0                               040843;0                     408823;0
#
#                                                 e  \
# Chiral indice n  Calculated atomic coordinates u'
# ...

# %%
#checkin data types of columns
df.dtypes #object is just a string
# Out:
# a    object
# b    object
# c    object
# d    object
# e    object
# f    object
# dtype: object

# %%
df.columns #lists columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df['a']
# Out:
# Chiral indice n    Chiral indice m
# 2;1;0                     679005;0
# 2;1;0                     717298;0
# 2;1;0                     489336;0
# 2;1;0                     413957;0
#                         ...
# 12;6;0                    834201;0
# 12;6;0                    698374;0
# 12;6;0                    923823;0
# 12;6;0                    934978;0
# 12;6;0                    953664;0
# Name: a, Length: 10722, dtype: object

# %%
x = df['a']
type(x)
# Out:
# pandas.core.series.Series

# %%
#df['a','b'] #it will give error.pass list of column
name = df[['a','b']]
name
# Out:
#                                a                            b
# Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 2;1;0                   679005;0                     701318;0
# 2;1;0                   717298;0                     642129;0
# 2;1;0                   489336;0                     303751;0
# 2;1;0                   413957;0                     632996;0
# ...                          ...                          ...
# 12;6;0                  834201;0                     399891;0
# 12;6;0                  698374;0                      24471;0
# 12;6;0                  923823;0                     568913;0
# 12;6;0                  934978;0                     602319;0
# 12;6;0                  953664;0                     698374;0
#
# [10722 rows x 2 columns]

# %%
type(name)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['a']) #single column gives series
# Out:
# pandas.core.series.Series

# %%
type(df[['a']]) #double column gives dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A66-F804
#
#  Directory of C:\Users\Rokaya Neeraj\Full Stack Data Science\Python\Pandas
#
# 03/28/2022  02:27 PM    <DIR>          .
# 03/28/2022  02:27 PM    <DIR>          ..
# 03/28/2022  01:41 PM    <DIR>          .ipynb_checkpoints
# 03/28/2022  02:27 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 03/28/2022  02:27 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 03/28/2022  02:27 PM            24,471 LUSID Excel - Manage instruments with economic definitions.xlsx
# 03/28/2022  02:27 PM            84,319 LUSID Excel - Manage Orders.xlsx
# 03/28/2022  02:27 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 03/28/2022  02:27 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 03/28/2022  02:27 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')
df.sheet_names #check all the sheets in the excel file
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    x = pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = i)
    print(x)
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
#In github, go to raw and then you can directly paste the link to read the csv file
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1.to_csv('NBA.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A66-F804
#
#  Directory of C:\Users\Rokaya Neeraj\Full Stack Data Science\Python\Da13-Pandas
#
# 03/29/2022  12:08 PM    <DIR>          .
# 03/29/2022  12:08 PM    <DIR>          ..
# 03/28/2022  01:41 PM    <DIR>          .ipynb_checkpoints
# 03/28/2022  02:27 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 03/28/2022  02:27 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 03/28/2022  02:27 PM            24,471 LUSID Excel - Manage instruments with economic definitions.xlsx
# 03/28/2022  02:27 PM            84,319 LUSID Excel - Manage Orders.xlsx
# 03/28/2022  02:27 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 03/28/2022  02:27 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 03/28/2022  02:27 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# ...

# %%
df1.to_csv('NBA.csv')

# %%
z = pd.read_csv("NBA.csv")
z
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1      Quincy Acy  PF  24  NYK  68  22  1287  152  ...
# 1             1    2    Jordan Adams  SG  20  MEM  30   0   248   35  ...
# 2             2    3    Steven Adams   C  21  OKC  70  67  1771  217  ...
# 3             3    4     Jeff Adrien  PF  28  MIN  17   0   215   19  ...
# 4             4    5   Arron Afflalo  SG  29  TOT  78  72  2502  375  ...
# ..          ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# ...

# %%
import pandas as pd
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1 = df[0]

# %%
df1.to_csv('NBA2.csv',index = False)

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
l
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
# ...

# %%
l[0].to_csv('criket.csv',index = False)

# %%
len(l)
# Out:
# 3

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
#convering dictionary into dataframe
d = """
{"name": "Niraj Rokaya",
"email_id":"rokayaneeraj@gmail.com",
"tech":["ML","DL","CV","NLP","RL","BD","DA"],
"platform":["techneuron","kidsneuron","ineuron"]
}
""" #check json viewer in google and paste the data to validate

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Niraj Rokaya',
#  'email_id': 'rokayaneeraj@gmail.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
pd.DataFrame(result) #if we remove NLP,RL,BD and Da than it will work
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ROKAYA~1\AppData\Local\Temp/ipykernel_7908/3023930414.py in <module>
# ----> 1 pd.DataFrame(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
d1 = d = """
{"name": "Niraj Rokaya",
"email_id":"rokayaneeraj@gmail.com",
"tech":["ML","DL","CV"],
"platform":["techneuron","kidsneuron","ineuron"],
"random": []
}
"""

# %%
import json
x = json.loads(d1)
x
# Out:
# {'name': 'Niraj Rokaya',
#  'email_id': 'rokayaneeraj@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron'],
#  'random': []}

# %%
pd.DataFrame(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ROKAYA~1\AppData\Local\Temp/ipykernel_7908/3634901035.py in <module>
# ----> 1 pd.DataFrame(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
del x['random'] #deleting the empty list to match the number of data in the list

# %%
pd.DataFrame(x)
# Out:
#            name                email_id tech    platform
# 0  Niraj Rokaya  rokayaneeraj@gmail.com   ML  techneuron
# 1  Niraj Rokaya  rokayaneeraj@gmail.com   DL  kidsneuron
# 2  Niraj Rokaya  rokayaneeraj@gmail.com   CV     ineuron

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
import pandas as pd
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %% [markdown]
# ### Trying to fecth user

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data #indicates successful
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46570',
#   'id': 1185906280,
#   'node_id': 'PR_kwDOAA0YD841SPuI',
#   'number': 46570,
#   'title': 'POC For docker compose',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
# ...

# %%
len(data1) #shows the number of dictionary present
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46570/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46570',
#  'id': 1185906280,
#  'node_id': 'PR_kwDOAA0YD841SPuI',
#  'number': 46570,
#  'title': 'POC For docker compose',
#  'user': {'login': 'WillAyd',
#   'id': 609873,
#   'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/WillAyd',
#   'html_url': 'https://github.com/WillAyd',
#   'followers_url': 'https://api.github.com/users/WillAyd/followers',
# ...

# %%
data1[0]['user']['id'] #printing id at 0 index
# Out:
# 609873

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id']) #printing all id
# Out:
# 609873
# 89279983
# 8078968
# 10647082
# 5728311
# 13159005
# 175722
# 33491632
# 66919765
# 33491632
# 45562402
# 291575
# 291575
# 4476168
# 15173842
# 72529861
# 30088608
# 24256554
# 41546976
# 45976948
# 45976948
# 6355796
# 175722
# 26720860
# 609873
# 22035922
# 45562402
# 36619387
# 26720860
# 4476168

# %% [markdown]
# ### obtaining urls

# %%
df2= pd.DataFrame(data1,columns=['url','repository_url','labels_url','user'])
df2
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df2.to_csv('json_res.csv',index = False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A66-F804
#
#  Directory of C:\Users\Rokaya Neeraj\Full Stack Data Science\Python\Da13-Pandas
#
# 03/30/2022  01:19 PM    <DIR>          .
# 03/30/2022  01:19 PM    <DIR>          ..
# 03/28/2022  01:41 PM    <DIR>          .ipynb_checkpoints
# 03/29/2022  12:37 PM             5,658 criket.csv
# 03/30/2022  01:19 PM            34,268 json_res.csv
# 03/28/2022  02:27 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 03/28/2022  02:27 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 03/28/2022  02:27 PM            24,471 LUSID Excel - Manage instruments with economic definitions.xlsx
# 03/28/2022  02:27 PM            84,319 LUSID Excel - Manage Orders.xlsx
# 03/28/2022  02:27 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# ...

# %% [markdown]
# ### from the above created json, make new columns for the user by the respective title heads present in the user column

# %%
import pandas
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)
data
# Out:
# <Response [200]>

# %%
data1 = data.json()
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46582',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46582/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46582/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46582/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46582',
#   'id': 1187859377,
#   'node_id': 'I_kwDOAA0YD85GzUux',
#   'number': 46582,
#   'title': 'BUG: pandas cannot recognize date objects as datetime like values',
#   'user': {'login': 'dcsaba89',
#    'id': 54766615,
#    'node_id': 'MDQ6VXNlcjU0NzY2NjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54766615?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dcsaba89',
#    'html_url': 'https://github.com/dcsaba89',
# ...

# %%
df = pd.DataFrame(data1)
df.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %% [markdown]
# ### DAY ---    3

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Understanding data

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Describing object columns

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object']#means, show all the dataype of object where datatype is object
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df.dtypes[df.dtypes == 'object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Adding new column

# %%
df['ineuron'] = "sudh"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Ticket']] #selecting columns
# Out:
#                                                   Name            Ticket
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
# [891 rows x 2 columns]

# %%
df['Name'][0:15] #slicing
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
ind = df[df['Age'].isnull() == True].index

# %%
len(ind)
# Out:
# 177

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#OR
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Number of male passanger

# %%
z = df[df['Sex'] == 'male']
male_count = len(z)
print(male_count)
#ans - 577 male passanger
# Out:
# 577

# %%
#'OR'
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# 'OR'
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# ### Number of female passanger

# %%
y = df[df['Sex'] == 'female']
female_count = len(y)
print(female_count)
#ans - 314 female passanger
# Out:
# 314

# %% [markdown]
# ### how many survived?

# %%
x = df[df['Survived'] == 1]
survived_count = len(x)
print(survived_count)
#Ans - 342 survived
# Out:
# 342

# %%
#'OR'
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#'OR'
df.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### how many casualty?

# %%
x = df[df['Survived'] == 0]
casualty_count = len(x)
print(casualty_count)
#Ans  - 549 casualty
# Out:
# 549

# %% [markdown]
# ### what is a name of a person who is the eldest one?

# %%
max(df['Age'])
# Out:
# 80.0

# %%
df[df['Age'] == max(df['Age'])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df[df['Age'] == max(df['Age'])]['Name']
#ans - Barkworth, Mr. Algernon Henry Wilson
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# ### 4. how many passanger do we have in 1,2,3 class

# %%
passager_firstclass= df[df['Pclass'] == 1]
print(len(passager_firstclass))
### 216 passanger in 1st class
# Out:
# 216

# %%
'OR'
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
'OR'
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
passager_secondclass= df[df['Pclass'] == 2]
print(len(passager_secondclass))
### 184 passanger in 2nd class
# Out:
# 184

# %%
passager_thirdclass= df[df['Pclass'] == 3]
print(len(passager_thirdclass))
### 491 passanger in 3rd class
# Out:
# 491

# %% [markdown]
# ### 5. how many person do we have who name starts with 's'

# %%
sname = df[df.Name.str.startswith("S")]['Name']
len(sname)
### 86 peoples name start with s
# Out:
# 86

# %% [markdown]
# ### 6. try to create a new column which is the summation of 'sibsp' and 'parch'

# %%
df['New Column'] = df['SibSp'] + df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New Column
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %% [markdown]
# ### 7. how many person below age 25

# %%
lessthan_twentyfive = df[df['Age'] < 25 ]['Age']
len(lessthan_twentyfive )
### 278 peoples have age below 25
# Out:
# 278

# %% [markdown]
# ### 8. how many person died whose age was less than 40

# %%
result = df[(df['Survived']) == 0 & (df['Age'] < 40)] 
len(result)
#549 person died whose age was less than 40
# Out:
# 549

# %% [markdown]
# ### 9. from a cabin column separate text and numeric

# %%
import re
df1 = df
replace = re.compile("([a-zA-Z]+)")

df1['Cabin_numbers'] = df1['Cabin'].str.extract(replace)
df1['Cabin_characters'] = df1['Cabin'].str.replace(replace,"")
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked numbers characters  \
# 0      0         A/5 21171   7.2500   NaN        S     NaN        NaN
# 1      0          PC 17599  71.2833   C85        C       C         85
# 2      0  STON/O2. 3101282   7.9250   NaN        S     NaN        NaN
#
#   Cabin_numbers Cabin_characters
# 0           NaN              NaN
# 1             C               85
# 2           NaN              NaN

# %% [markdown]
# ### ----Questions from bank.csv

# %%
import pandas as pd
df = pd.read_csv('Bank.csv',delimiter = ';')
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ### 1. How many campaign available in this dataset

# %%
len(df['campaign'].unique())
#32 campaign
# Out:
# 32

# %%
#"OR"
len(set(df['campaign'])) #first select campaign column.Then converted it to set because set gives us unique element.Now, if we 
# print the length of it, it will give us the number of campaign.
# Out:
# 32

# %% [markdown]
# ### 2. How many users do we have with housing and personal loan

# %%
h_p_loan = df[(df['housing'] == 'yes') & (df['loan'] == 'yes')]
print(len(h_p_loan))
# 406 users have both housing and personal loan.
# Out:
# 406

# %% [markdown]
# ### 3. How many person do we have whose age is 60+.

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
sixty_plus = df[df['age'] > 60]
print(len(sixty_plus))
#127 person has age above 60.
# Out:
# 127

# %% [markdown]
# ### 4. In which month we have targeted most of the customer

# %%
df2 = df.groupby('month')['month'].count()
print(df2)
#from the result, we can see that, we have targeted most of the customer in  may.
# Out:
# month
# apr     293
# aug     633
# dec      20
# feb     222
# jan     148
# jul     706
# jun     531
# mar      49
# may    1398
# nov     389
# oct      80
# sep      52
# Name: month, dtype: int64

# %%
df['month'].value_counts().sort_values(ascending = False)
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %% [markdown]
# ### 5. Which mode of call is giving you a more result.

# %%
df2 = df
df2 = df2.groupby(['contact','y']).count()
df2
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
df2.loc['cellular','yes'][0]
# Out:
# 416

# %%
max(df2.loc['cellular','yes'][0],df2.loc['telephone','yes'][0],df2.loc['unknown','yes'][0])
# Out:
# 416

# %%
# we can conclued that cellular mode of call gives more result.

# %% [markdown]
# ### 6. How many entrpreneurs do we have in this list.

# %%
count_entrepreneur = df[df['job'] == 'entrepreneur']
print(len(count_entrepreneur))
#168 peoples in the data are entrepreneur.

# %% [markdown]
# ### 7. How many customers do we have with negative balance.

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
len(df[df['balance'] < 0])
# Out:
# 366

# %% [markdown]
# ### 8. Prepare a group of data based on education level.

# %%
l=[]
for  i in df['education'].unique():
    l.append(df[df['education'] == i])

# %%
l[0].head(2)
# Out:
#    age         job  marital education default  balance housing loan   contact  \
# 0   30  unemployed  married   primary      no     1787      no   no  cellular
# 9   43    services  married   primary      no      -88     yes  yes  cellular
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0   19   oct        79         1     -1         0  unknown  no
# 9   17   apr       313         1    147         2  failure  no

# %%
l[1].head(2)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 1   33     services  married  secondary      no     4789     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 1  cellular   11   may       220         1    339         4  failure  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l[2].head(2)
# Out:
#    age         job  marital education default  balance housing loan   contact  \
# 2   35  management   single  tertiary      no     1350     yes   no  cellular
# 3   30  management  married  tertiary      no     1476     yes  yes   unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 2   16   apr       185         1    330         1  failure  no
# 3    3   jun       199         4     -1         0  unknown  no

# %%
l[3].head(2)
# Out:
#     age         job   marital education default  balance housing loan  \
# 20   38  management  divorced   unknown      no        0     yes   no
# 27   67     retired   married   unknown      no      696      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 20   cellular   18   nov        96         2     -1         0  unknown  no
# 27  telephone   17   aug       119         1    105         2  failure  no

# %% [markdown]
# ### task
#
# read all the resume from ineuron git in pdf,word and try to create a dataframe with resume name as a index value, and
#
# in column, i am expecting email id, linkedin id. git id , skills. Use regular expression

# %% [markdown]
# ###  DAY - 4

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.dropna().head(2) #dropping row where NAN values
#axis = 0 means rows and axis = 1 means column
#no changes in original dataframe.If we have to change the dataframe permanently, we can do,df.dropna(inplace = True)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis = 1,thresh =800) #thresh means there should be that many number of non nan values for not dropping
#press shift tab after df.dropna so that we can get definition of everything possible that we can enter
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df['Age']= df['Age'].fillna(value = df['Age'].mean()) #filling age column nan value with average of age
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby('Survived').describe()['PassengerId'].transpose() #transpose chanes row to column and viceversa
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
import pandas as pd
df1 = pd.read_csv('Bank.csv', sep = ";")
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i])

# %%
df2 = l[0].head()
df2
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df3 = l[1].head()
df3
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([df2,df3]) #row wise concatination
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 9    43     services   married    primary      no      -88     yes  yes
# 18   25  blue-collar    single    primary      no     -221     yes   no
# 26   55  blue-collar   married    primary      no      627     yes   no
# 36   78      retired  divorced    primary      no      229      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# 7    39   technician   married  secondary      no      147     yes   no
# 10   39     services   married  secondary      no     9374     yes   no
# 11   43       admin.   married  secondary      no      264     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# ...

# %%
pd.concat([df2,df3],axis = 1) #column wise concatination
# Out:
#      age          job   marital education default  balance housing loan  \
# 0   30.0   unemployed   married   primary      no   1787.0      no   no
# 1    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 4    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 7    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 9   43.0     services   married   primary      no    -88.0     yes  yes
# 10   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 11   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 18  25.0  blue-collar    single   primary      no   -221.0     yes   no
# 26  55.0  blue-collar   married   primary      no    627.0     yes   no
# 36  78.0      retired  divorced   primary      no    229.0      no   no
#
#       contact   day  ... loan   contact   day  month  duration campaign  \
# 0    cellular  19.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# ...

# %%
df2 = df2.head()[['age','job','marital']]

# %%
df3 = df3.head()[['age','job','marital']]

# %%
df5 = pd.concat([df2,df3],axis = 1) #try to match index
df5
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 9   43.0     services   married   NaN          NaN      NaN
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN

# %% [markdown]
# #### try to select second age column

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 9   43.0   NaN
# 10   NaN  39.0
# 11   NaN  43.0
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN

# %%
df5.iloc[:,3] # iloc takes default index
# Out:
# 0      NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 9      NaN
# 10    39.0
# 11    43.0
# 18     NaN
# 26     NaN
# 36     NaN
# Name: age, dtype: float64

# %%
df5.iloc[[4,5],[3,4]] #[4,5] is the default row index. [3,4] is the column index
# Out:
#      age       job
# 9    NaN       NaN
# 10  39.0  services

# %%
df5.loc[[9,10],['age']] #[9,10] is the row index actual row index. ['age'] selects column
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %% [markdown]
# ### Select index 9 and index 18 value from job and marital columns

# %%
df2.loc[[9,18],['job','marital']] #using loc
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[[1,2],[1,2]] #using iloc
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %% [markdown]
# ### Concat function concatenates dataframes along rows or columns. We can think of it as stacking up multiple dataframes. Merge combines dataframes based on values in shared columns. Merge function offers more flexibility compared to concat function because it allows combinations based on a condition.

# %%
pd.merge(df2,df3,on='age') #by default, its inner join. So, only common element values are printed
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
x = pd.merge(df2,df3,how = 'left',on ='age')
x
# Out:
#            job_x marital_x   job_y marital_y
# age
# 30    unemployed   married     NaN       NaN
# 43      services   married  admin.   married
# 25   blue-collar    single     NaN       NaN
# 55   blue-collar   married     NaN       NaN
# 78       retired  divorced     NaN       NaN

# %%
pd.merge(df2,df3,how = 'outer',on = 'age')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %% [markdown]
# ### join in pandas

# %%
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
x
# Out:
#            job_x marital_x   job_y marital_y
# age
# 30    unemployed   married     NaN       NaN
# 43      services   married  admin.   married
# 25   blue-collar    single     NaN       NaN
# 55   blue-collar   married     NaN       NaN
# 78       retired  divorced     NaN       NaN

# %%
j = df3.join(x)
j
# Out:
#              job  marital     job_x marital_x   job_y marital_y
# age
# 33      services  married       NaN       NaN     NaN       NaN
# 39    technician  married       NaN       NaN     NaN       NaN
# 39      services  married       NaN       NaN     NaN       NaN
# 43        admin.  married  services   married  admin.   married
# 59   blue-collar  married       NaN       NaN     NaN       NaN

# %%
j = j.reset_index()# will change the index to column
j
# Out:
#    age          job  marital     job_x marital_x   job_y marital_y
# 0   33     services  married       NaN       NaN     NaN       NaN
# 1   39   technician  married       NaN       NaN     NaN       NaN
# 2   39     services  married       NaN       NaN     NaN       NaN
# 3   43       admin.  married  services   married  admin.   married
# 4   59  blue-collar  married       NaN       NaN     NaN       NaN

# %%
j.set_index('age') # will set column to index
# Out:
#              job  marital     job_x marital_x   job_y marital_y
# age
# 33      services  married       NaN       NaN     NaN       NaN
# 39    technician  married       NaN       NaN     NaN       NaN
# 39      services  married       NaN       NaN     NaN       NaN
# 43        admin.  married  services   married  admin.   married
# 59   blue-collar  married       NaN       NaN     NaN       NaN
