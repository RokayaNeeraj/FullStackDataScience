# %%
import json
import pymongo
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://assignment:assignment@cluster0.hq5yf.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %%
db2 = client['carbon_nanotubes']#creating database
collection = db2['nanotube']

# %%
df = pd.read_csv('C:/Users/Rokaya Neeraj/Downloads/carbon_nanotubes.csv',encoding = 'ISO-8859-1')   # loading csv file
df.to_json('carbon.json')                               # saving to json file
jdf = open('carbon.json').read()                        # loading the json file 
data = json.loads(jdf)                                  # reading json file

# %%
with open('carbon.json') as file:
    file_data = json.load(file)

# %%
for file in file_data:
    collection.insert_many([file_data[file]])

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('623da5d703ae0174cda86d4b'), '0': '2;1;0', '1': '2;1;0', '2': '2;1;0', '3': '2;1;0', '4': '2;1;0', '5': '2;1;0', '6': '2;1;0', '7': '2;1;0', '8': '2;1;0', '9': '2;1;0', '10': '2;1;0', '11': '2;1;0', '12': '2;1;0', '13': '2;1;0', '14': '2;1;0', '15': '2;1;0', '16': '2;1;0', '17': '2;1;0', '18': '2;1;0', '19': '2;1;0', '20': '2;1;0', '21': '2;1;0', '22': '2;1;0', '23': '2;1;0', '24': '2;1;0', '25': '2;1;0', '26': '2;1;0', '27': '2;1;0', '28': '3;1;0', '29': '3;1;0', '30': '3;1;0', '31': '3;1;0', '32': '3;1;0', '33': '3;1;0', '34': '3;1;0', '35': '3;1;0', '36': '3;1;0', '37': '3;1;0', '38': '3;1;0', '39': '3;1;0', '40': '3;1;0', '41': '3;1;0', '42': '3;1;0', '43': '3;1;0', '44': '3;1;0', '45': '3;1;0', '46': '3;1;0', '47': '3;1;0', '48': '3;1;0', '49': '3;1;0', '50': '3;1;0', '51': '3;1;0', '52': '3;1;0', '53': '3;1;0', '54': '3;1;0', '55': '3;1;0', '56': '3;1;0', '57': '3;1;0', '58': '3;1;0', '59': '3;1;0', '60': '3;1;0', '61': '3;1;0', '62': '3;1;0', '63': '3;1;0', '6
# ...
